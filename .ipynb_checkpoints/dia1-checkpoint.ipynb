# %% [markdown]
# ## Imports e funcs

# %%
import pandas as pd
import numpy as np


from sklearn.model_selection import (
    train_test_split, KFold)
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import (
    OneHotEncoder, OrdinalEncoder, MinMaxScaler, StandardScaler)

import matplotlib.pyplot as plt
import seaborn as sns

# %%
def plotbar(df, x_column, horizontal=False):
    counts = df[x_column].value_counts()
    
    plt.figure(figsize=(10, 6))  # Ajuste o tamanho conforme necessário
    
    if horizontal:
        bars = plt.barh(counts.index, counts.values)
        plt.xlabel('Quantidade')
        plt.ylabel(x_column)
    else:
        bars = plt.bar(counts.index, counts.values)
        plt.xlabel(x_column)
        plt.ylabel('Quantidade')
    
    plt.title('Gráfico de Barras')
    
    # Adicionar os valores do eixo y nas barras
    for bar in bars:
        if horizontal:
            width = bar.get_width()
            plt.text(width, bar.get_y() + bar.get_height() / 2, str(int(width)), ha='left', va='center')
        else:
            height = bar.get_height()
            plt.text(bar.get_x() + bar.get_width() / 2, height, str(int(height)), ha='center', va='bottom')
    
    plt.show()

# %%
def cls_feature(X):
        #Agrupando features numéricas
    numeric_features  = [cls for cls in X.columns if X[cls].dtype == 'float64' or X[cls].dtype =='int64']
    # print('>>numeric_features:', numeric_features ,
          # len(numeric_features))


    #Agrupando features categoricas
    cat_features = [cls for cls in X.columns if X[cls].dtypes == 'object' and X[cls].nunique()<=max_cat]
    # print('\n>>cat_features:', cat_features ,
          # len(cat_features))
    return numeric_features , cat_features

# %% [markdown]
# ## Start

# %%
data_train = pd.read_csv('data/train.csv')
data_test =  pd.read_csv('data/test.csv')

# %%
data_train
# Out:
#       id_do_caso        continente educacao_do_empregado  \
# 0      EZYV10567            Europa          Ensino Médio
# 1       EZYV5505              Ásia              Mestrado
# 2       EZYV5207              Ásia          Ensino Médio
# 3       EZYV7545              Ásia          Ensino Médio
# 4      EZYV16071              Ásia       Ensino Superior
# ...          ...               ...                   ...
# 17831  EZYV17821              Ásia              Mestrado
# 17832  EZYV13200            Europa          Ensino Médio
# 17833   EZYV8903  América do Norte              Mestrado
# 17834   EZYV6163  América do Norte             Doutorado
# 17835   EZYV4219              Ásia       Ensino Superior
#
#       tem_experiencia_de_trabalho requer_treinamento_de_trabalho  \
# 0                               N                              S
# 1                               S                              N
# 2                               N                              N
# 3                               N                              N
# 4                               S                              N
# ...                           ...                            ...
# 17831                           S                              N
# 17832                           N                              N
# 17833                           N                              N
# 17834                           S                              N
# 17835                           S                              N
#
#        num_de_empregados  ano_de_estabelecimento regiao_de_emprego  \
# 0                   2087                    1855               Sul
# 1                   5991                    2003        Meio-Oeste
# 2                   1426                    2000              Ilha
# 3                   3846                    1992        Meio-Oeste
# 4                   3957                    1949          Nordeste
# ...                  ...                     ...               ...
# 17831              95347                    1995             Oeste
# 17832               1483                    1886               Sul
# 17833               1504                    2010          Nordeste
# 17834             251967                    2010        Meio-Oeste
# 17835               4116                    2008             Oeste
#
#        salario_prevalecente unidade_de_salario posicao_em_tempo_integral  \
# 0                  69711.24                Ano                         S
# 1                  52931.38                Ano                         S
# 2                 110830.21                Ano                         S
# 3                  91884.68             Semana                         S
# 4                 138155.24                Ano                         S
# ...                     ...                ...                       ...
# 17831              69692.24                Ano                         S
# 17832             136237.62                Ano                         S
# 17833             118187.30                Ano                         S
# 17834              93133.40                Ano                         S
# 17835              71500.57                Ano                         S
#
#       status_do_caso
# 0             Negado
# 1           Aprovado
# 2             Negado
# 3             Negado
# 4           Aprovado
# ...              ...
# 17831       Aprovado
# 17832         Negado
# 17833         Negado
# 17834       Aprovado
# 17835       Aprovado
#
# [17836 rows x 12 columns]

# %%
data_train.columns
# Out:
# Index(['id_do_caso', 'continente', 'educacao_do_empregado',
#        'tem_experiencia_de_trabalho', 'requer_treinamento_de_trabalho',
#        'num_de_empregados', 'ano_de_estabelecimento', 'regiao_de_emprego',
#        'salario_prevalecente', 'unidade_de_salario',
#        'posicao_em_tempo_integral', 'status_do_caso'],
#       dtype='object')

# %%
data_train.drop(columns='id_do_caso',inplace=True) # removendo feature que não ajudará no modelo

# %%
X = data_train.drop(columns='status_do_caso')
y = data_train['status_do_caso']

# %% [markdown]
# ## EDA

# %%
data_train.describe()
# Out:
#        num_de_empregados  ano_de_estabelecimento  salario_prevalecente
# count        17836.00000            17836.000000          17836.000000
# mean          5726.50185             1979.494898          74327.428401
# std          23321.37739               42.097194          52795.859573
# min            -26.00000             1800.000000              2.136700
# 25%           1023.00000             1976.000000          33892.912500
# 50%           2117.00000             1997.000000          70106.920000
# 75%           3504.25000             2005.000000         107564.715000
# max         602069.00000             2016.000000         319210.270000

# %%
data_train.describe(exclude = np.number)
# Out:
#        continente educacao_do_empregado tem_experiencia_de_trabalho  \
# count       17836                 17836                       17836
# unique          6                     4                           2
# top          Ásia       Ensino Superior                           S
# freq        11765                  7151                       10380
#
#        requer_treinamento_de_trabalho regiao_de_emprego unidade_de_salario  \
# count                           17836             17836              17836
# unique                              2                 5                  4
# top                                 N          Nordeste                Ano
# freq                            15755              5064              16089
#
#        posicao_em_tempo_integral status_do_caso
# count                      17836          17836
# unique                         2              2
# top                            S       Aprovado
# freq                       15934          11937

# %%
data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17836 entries, 0 to 17835
# Data columns (total 12 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id_do_caso                      17836 non-null  object
#  1   continente                      17836 non-null  object
#  2   educacao_do_empregado           17836 non-null  object
#  3   tem_experiencia_de_trabalho     17836 non-null  object
#  4   requer_treinamento_de_trabalho  17836 non-null  object
#  5   num_de_empregados               17836 non-null  int64
#  6   ano_de_estabelecimento          17836 non-null  int64
#  7   regiao_de_emprego               17836 non-null  object
#  8   salario_prevalecente            17836 non-null  float64
#  9   unidade_de_salario              17836 non-null  object
#  10  posicao_em_tempo_integral       17836 non-null  object
#  11  status_do_caso                  17836 non-null  object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 1.6+ MB

# %%
data_train.isna().sum()
# Out:
# id_do_caso                        0
# continente                        0
# educacao_do_empregado             0
# tem_experiencia_de_trabalho       0
# requer_treinamento_de_trabalho    0
# num_de_empregados                 0
# ano_de_estabelecimento            0
# regiao_de_emprego                 0
# salario_prevalecente              0
# unidade_de_salario                0
# posicao_em_tempo_integral         0
# status_do_caso                    0
# dtype: int64

# %%
### Não possuimos valores ausentes

# %%
sns.heatmap(data_train.isnull(),cbar = False)
plt.show()

# %%
plotbar(data_train,'continente',horizontal=True)

# %%
plotbar(data_train,'educacao_do_empregado',horizontal=True)

# %%
plotbar(X,'requer_treinamento_de_trabalho')

# %% [markdown]
# ## Prepro

# %%
num_features,cat_features = cls_feature(data_train)

# %%
num_features # feature numericas
# Out:
# ['num_de_empregados', 'ano_de_estabelecimento', 'salario_prevalecente']

# %%
cat_features #features categoricas
# Out:
# ['continente',
#  'educacao_do_empregado',
#  'tem_experiencia_de_trabalho',
#  'requer_treinamento_de_trabalho',
#  'regiao_de_emprego',
#  'unidade_de_salario',
#  'posicao_em_tempo_integral',
#  'status_do_caso']

# %%
df = data_train.copy()

# %%
Xtrain,Xtest,ytrai,ytest = train_test_split(X,y,train_size=0.8,random_state=42)

# %%
# Pipeline

pipeline_categorico = Pipeline([
        ('encoder',OneHotEncoder()) # one hot enconder
    
])

pipeline_numerico = Pipeline([
    ('scaler',StandardScaler())
])

preprocessor = ColumnTransformer([
    ('preprocessor_categorico' , pipeline_categorico,cat_features),
    ('preprocessor_numerico'   , pipeline_numerico,num_features)
])

# %%
X_train_preprocessed = preprocessor.fit_transform(Xtrain)
X_test_preprocessed = preprocessor.transform(Xtest)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda/envs/ml/lib/python3.8/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File /opt/anaconda/envs/ml/lib/python3.8/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/anaconda/envs/ml/lib/python3.8/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'status_do_caso'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda/envs/ml/lib/python3.8/site-packages/sklearn/utils/__init__.py:448, in _get_column_indices(X, key)
#     447 for col in columns:
# --> 448     col_idx = all_columns.get_loc(col)
#     449     if not isinstance(col_idx, numbers.Integral):
#
# File /opt/anaconda/envs/ml/lib/python3.8/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key, method, tolerance)
#    3804 except KeyError as err:
# -> 3805     raise KeyError(key) from err
#    3806 except TypeError:
#    3807     # If we have a listlike key, _check_indexing_error will raise
#    3808     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3809     #  the TypeError.
#
# KeyError: 'status_do_caso'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[135], line 1
# ----> 1 X_train_preprocessed = preprocessor.fit_transform(Xtrain)
#       2 X_test_preprocessed = preprocessor.transform(Xtest)
#
# File /opt/anaconda/envs/ml/lib/python3.8/site-packages/sklearn/utils/_set_output.py:142, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     140 @wraps(f)
#     141 def wrapped(self, X, *args, **kwargs):
# --> 142     data_to_wrap = f(self, X, *args, **kwargs)
#     143     if isinstance(data_to_wrap, tuple):
#     144         # only wrap the first output for cross decomposition
#     145         return (
#     146             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     147             *data_to_wrap[1:],
#     148         )
#
# File /opt/anaconda/envs/ml/lib/python3.8/site-packages/sklearn/compose/_column_transformer.py:723, in ColumnTransformer.fit_transform(self, X, y)
#     721 self._check_n_features(X, reset=True)
#     722 self._validate_transformers()
# --> 723 self._validate_column_callables(X)
#     724 self._validate_remainder(X)
#     726 result = self._fit_transform(X, y, _fit_transform_one)
#
# File /opt/anaconda/envs/ml/lib/python3.8/site-packages/sklearn/compose/_column_transformer.py:425, in ColumnTransformer._validate_column_callables(self, X)
#     423         columns = columns(X)
#     424     all_columns.append(columns)
# --> 425     transformer_to_input_indices[name] = _get_column_indices(X, columns)
#     427 self._columns = all_columns
#     428 self._transformer_to_input_indices = transformer_to_input_indices
#
# File /opt/anaconda/envs/ml/lib/python3.8/site-packages/sklearn/utils/__init__.py:456, in _get_column_indices(X, key)
#     453             column_indices.append(col_idx)
#     455     except KeyError as e:
# --> 456         raise ValueError("A given column is not a column of the dataframe") from e
#     458     return column_indices
#     459 else:
#
# ValueError: A given column is not a column of the dataframe
