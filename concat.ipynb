# %%
import pandas as pd

# %%
train_data = pd.read_csv('data/atual_train.csv')
test_data = pd.read_csv('data/test.csv')

# %%
train_data
# Out:
#       id_do_caso        continente educacao_do_empregado  \
# 0      EZYV10567            Europa          Ensino Médio
# 1       EZYV5505              Ásia              Mestrado
# 2       EZYV5207              Ásia          Ensino Médio
# 3       EZYV7545              Ásia          Ensino Médio
# 4      EZYV16071              Ásia       Ensino Superior
# ...          ...               ...                   ...
# 17831  EZYV17821              Ásia              Mestrado
# 17832  EZYV13200            Europa          Ensino Médio
# 17833   EZYV8903  América do Norte              Mestrado
# 17834   EZYV6163  América do Norte             Doutorado
# 17835   EZYV4219              Ásia       Ensino Superior
#
#       tem_experiencia_de_trabalho requer_treinamento_de_trabalho  \
# 0                               N                              S
# 1                               S                              N
# 2                               N                              N
# ...

# %%
test_data
# Out:
#      id_do_caso        continente educacao_do_empregado  \
# 0     EZYV22339              Ásia       Ensino Superior
# 1      EZYV9333              Ásia              Mestrado
# 2      EZYV9740              Ásia       Ensino Superior
# 3      EZYV3328              Ásia       Ensino Superior
# 4     EZYV12321    América do Sul       Ensino Superior
# ...         ...               ...                   ...
# 7639  EZYV19907  América do Norte       Ensino Superior
# 7640    EZYV576              Ásia          Ensino Médio
# 7641   EZYV1804              Ásia              Mestrado
# 7642  EZYV13543  América do Norte              Mestrado
# 7643  EZYV17903              Ásia       Ensino Superior
#
#      tem_experiencia_de_trabalho requer_treinamento_de_trabalho  \
# 0                              S                              N
# 1                              N                              S
# 2                              S                              N
# ...

# %%
train_data['origem'] = 'treinamento'
test_data['origem'] = 'teste'

# %%
combined_data = pd.concat([train_data, test_data], ignore_index=True)

# %%
combined_data
# Out:
#       id_do_caso        continente educacao_do_empregado  \
# 0      EZYV10567            Europa          Ensino Médio
# 1       EZYV5505              Ásia              Mestrado
# 2       EZYV5207              Ásia          Ensino Médio
# 3       EZYV7545              Ásia          Ensino Médio
# 4      EZYV16071              Ásia       Ensino Superior
# ...          ...               ...                   ...
# 25475  EZYV19907  América do Norte       Ensino Superior
# 25476    EZYV576              Ásia          Ensino Médio
# 25477   EZYV1804              Ásia              Mestrado
# 25478  EZYV13543  América do Norte              Mestrado
# 25479  EZYV17903              Ásia       Ensino Superior
#
#       tem_experiencia_de_trabalho requer_treinamento_de_trabalho  \
# 0                               N                              S
# 1                               S                              N
# 2                               N                              N
# ...

# %%
# "Experiência de trabalho e requer treinamento", - 1
df.loc[(df['tem_experiencia_de_trabalho'] == 'S') & (df['requer_treinamento_de_trabalho'] == 'S'), 'cat_experiencia'] = '1'
# "Experiência de trabalho e não requer treinamento" - 2''
df.loc[(df['tem_experiencia_de_trabalho'] == 'S') & (df['requer_treinamento_de_trabalho'] == 'N'), 'cat_experiencia'] = '2'
# "Sem experiência de trabalho e requer treinamento" - 3''
df.loc[(df['tem_experiencia_de_trabalho'] == 'N') & (df['requer_treinamento_de_trabalho'] == 'S'), 'cat_experiencia'] = '3'
# "Sem experiência de trabalho e não requer - 4''
df.loc[(df['tem_experiencia_de_trabalho'] == 'N') & (df['requer_treinamento_de_trabalho'] == 'N'), 'cat_experiencia'] = '4'
