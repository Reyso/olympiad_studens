# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn import preprocessing
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler, OneHotEncoder, OrdinalEncoder
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV, StratifiedKFold, cross_val_predict
from sklearn.metrics import accuracy_score, roc_auc_score, f1_score, precision_score, recall_score, jaccard_score, log_loss, confusion_matrix
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier, ExtraTreeRegressor
from sklearn.naive_bayes import GaussianNB, BernoulliNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier

# %%
def cls_feature(X,max_cat = 10):
        #Agrupando features numéricas
    numeric_features  = [cls for cls in X.columns if X[cls].dtype == 'float64' or X[cls].dtype =='int64']
    # print('>>numeric_features:', numeric_features ,
          # len(numeric_features))


    #Agrupando features categoricas
    categorical_features = [cls for cls in X.columns if X[cls].dtypes == 'object' and X[cls].nunique()<=max_cat]
    # print('\n>>cat_features:', cat_features ,
          # len(cat_features))
    return numeric_features , categorical_features

# %%
def print_metrics(y_true, y_pred, y_pred_proba):
    
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred)
    recall = recall_score(y_true, y_pred)
    #f1 = f1_score(y_true, y_pred)
    logloss = log_loss(y_true, y_pred_proba)
    roc_auc = roc_auc_score(y_true, y_pred)

    print("Accuracy: {:.2f}".format(accuracy))
    print("Precision: {:.2f}".format(precision))
    print("Recall: {:.2f}".format(recall))
    #print("F1-Score: {:.2f}".format(f1))
    print("Log Loss: {:.2f}".format(logloss))
    print("ROC AUC Score: {:.2f}".format(roc_auc))

# %%
def custom_features(df):
    df_out = df.copy()
    df_out['cat_empresa'] = df_out['ano_de_estabelecimento'].apply(lambda x: 'antiga' if x <= 1945 else
                                                                    'intermediaria' if 1945 < x < 1996 else
                                                                    'nova' if x >= 1996 else 'NaN')
    percentil_25 = np.percentile(df['salario_prevalecente'], 25)
    percentil_75 = np.percentile(df['salario_prevalecente'], 75)
    median = np.median(df['salario_prevalecente'])
    df_out['cat_salario'] = df_out['salario_prevalecente'].apply(lambda x: 'baixo' if x < percentil_25 else
                                                                'medio_baixo' if percentil_25 <= x < median else
                                                                'medio_alto' if median <= x < percentil_75 else
                                                                'alto' if x >= percentil_75 else 'NaN')
    
    # df_out['cat_salario'] = df_out['salario_prevalecente'].apply(lambda x: 'baixo' if x < np.percentile(df['salario_prevalecente'], 25) else
    #                                                                'medio_baixo' if np.percentile(df['salario_prevalecente'], 25) <= x < np.median(df['salario_prevalecente']) else
    #                                                                'medio_alto' if np.median(df['salario_prevalecente']) <= x < np.percentile(df['salario_prevalecente'], 75) else
    #                                                                'alto' if x >= np.percentile(df['salario_prevalecente'], 75) else 'NaN')
    df_out['cat_experiencia'] = 'Null'
    df_out.loc[(df_out['tem_experiencia_de_trabalho'] == 'S') & (df_out['requer_treinamento_de_trabalho'] == 'S'), 'cat_experiencia'] = '1'
    df_out.loc[(df_out['tem_experiencia_de_trabalho'] == 'S') & (df_out['requer_treinamento_de_trabalho'] == 'N'), 'cat_experiencia'] = '2'
    df_out.loc[(df_out['tem_experiencia_de_trabalho'] == 'N') & (df_out['requer_treinamento_de_trabalho'] == 'S'), 'cat_experiencia'] = '3'
    df_out.loc[(df_out['tem_experiencia_de_trabalho'] == 'N') & (df_out['requer_treinamento_de_trabalho'] == 'N'), 'cat_experiencia'] = '4'
    
    return df_out

# %% [markdown]
# ## Data

# %%
data_train = pd.read_csv('data/train.csv'); data_train.head()
# Out:
#   id_do_caso continente educacao_do_empregado tem_experiencia_de_trabalho  \
# 0  EZYV10567     Europa          Ensino Médio                           N
# 1   EZYV5505       Ásia              Mestrado                           S
# 2   EZYV5207       Ásia          Ensino Médio                           N
# 3   EZYV7545       Ásia          Ensino Médio                           N
# 4  EZYV16071       Ásia       Ensino Superior                           S
#
#   requer_treinamento_de_trabalho  num_de_empregados  ano_de_estabelecimento  \
# 0                              S               2087                    1855
# 1                              N               5991                    2003
# 2                              N               1426                    2000
# 3                              N               3846                    1992
# 4                              N               3957                    1949
#
#   regiao_de_emprego  salario_prevalecente unidade_de_salario  \
# 0               Sul              69711.24                Ano
# 1        Meio-Oeste              52931.38                Ano
# 2              Ilha             110830.21                Ano
# 3        Meio-Oeste              91884.68             Semana
# 4          Nordeste             138155.24                Ano
#
#   posicao_em_tempo_integral status_do_caso
# 0                         S         Negado
# 1                         S       Aprovado
# 2                         S         Negado
# 3                         S         Negado
# 4                         S       Aprovado

# %%
df = data_train.copy()

# %%
df.drop(columns=['id_do_caso'],inplace = True)

# %%
df.head()
# Out:
#   continente educacao_do_empregado tem_experiencia_de_trabalho  \
# 0     Europa          Ensino Médio                           N
# 1       Ásia              Mestrado                           S
# 2       Ásia          Ensino Médio                           N
# 3       Ásia          Ensino Médio                           N
# 4       Ásia       Ensino Superior                           S
#
#   requer_treinamento_de_trabalho  num_de_empregados  ano_de_estabelecimento  \
# 0                              S               2087                    1855
# 1                              N               5991                    2003
# 2                              N               1426                    2000
# 3                              N               3846                    1992
# 4                              N               3957                    1949
#
#   regiao_de_emprego  salario_prevalecente unidade_de_salario  \
# 0               Sul              69711.24                Ano
# 1        Meio-Oeste              52931.38                Ano
# 2              Ilha             110830.21                Ano
# 3        Meio-Oeste              91884.68             Semana
# 4          Nordeste             138155.24                Ano
#
#   posicao_em_tempo_integral status_do_caso
# 0                         S         Negado
# 1                         S       Aprovado
# 2                         S         Negado
# 3                         S         Negado
# 4                         S       Aprovado

# %% [markdown]
# ## Start

# %%
df['status_do_caso'].value_counts()
# Out:
# Aprovado    11937
# Negado       5899
# Name: status_do_caso, dtype: int64

# %%
df['status_do_caso'] = df['status_do_caso'].apply(lambda x: 1 if x == 'Aprovado' else 0)

# %%
df['status_do_caso'].value_counts()
# Out:
# 1    11937
# 0     5899
# Name: status_do_caso, dtype: int64

# %%
df.dtypes
# Out:
# continente                         object
# educacao_do_empregado              object
# tem_experiencia_de_trabalho        object
# requer_treinamento_de_trabalho     object
# num_de_empregados                   int64
# ano_de_estabelecimento              int64
# regiao_de_emprego                  object
# salario_prevalecente              float64
# unidade_de_salario                 object
# posicao_em_tempo_integral          object
# status_do_caso                      int64
# dtype: object

# %%
X = df.drop(columns=['status_do_caso'])
y = df['status_do_caso']

# %%
df['ano_de_estabelecimento'] = np.log1p(df['ano_de_estabelecimento'])

# %% [markdown]
# ## Prepro

# %%
feature_engineering_transformer = FunctionTransformer(custom_features)

# %%
numeric_features , categorical_features = cls_feature(X)

# %%
numeric_features
# Out:
# ['num_de_empregados', 'ano_de_estabelecimento', 'salario_prevalecente']

# %%
categorical_features
# Out:
# ['continente',
#  'educacao_do_empregado',
#  'tem_experiencia_de_trabalho',
#  'requer_treinamento_de_trabalho',
#  'regiao_de_emprego',
#  'unidade_de_salario',
#  'posicao_em_tempo_integral']

# %%
from sklearn.decomposition import PCA

# Obtenha o número mínimo de componentes principais com base nas dimensões do conjunto de dados
n_components = 2

categorical_transformer = Pipeline([
    ('imputer',SimpleImputer(strategy='constant',fill_value='missing')),
    ('encoder',OneHotEncoder(handle_unknown='ignore',sparse=False)),
])

numerical_transformer = Pipeline([
    ('imputer',SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])

# Adicione o estágio de PCA ao pipeline
pca_transformer = Pipeline([
    ('scaler', StandardScaler()),
    ('pca', PCA(n_components=n_components))
])

preprocessor = ColumnTransformer([
    ("num", numerical_transformer, numeric_features),
    ("cat", categorical_transformer, categorical_features),
])

# Adicione o estágio de PCA ao preprocessor
preprocessor_with_pca = ColumnTransformer([
    ("num", pca_transformer, numeric_features),
    ("cat", categorical_transformer, categorical_features),
])

pipeline_fe = Pipeline(steps=[
    ('fe', feature_engineering_transformer),
    ('preprocessor', preprocessor_with_pca)
])

# %%
X_preprocessed_fe = pipeline_fe.fit_transform(X)

# %%
# Dividir os dados em conjuntos de treinamento e teste
X_train, X_test, y_train, y_test = train_test_split(X_preprocessed_fe, y, test_size=0.2, random_state=42)

# Definir os modelos
models = {
    'RandomForest': RandomForestClassifier(class_weight='balanced', random_state=42),
    'XGBoost': XGBClassifier(random_state=42,class_weight='balanced'),
    'LGBM': LGBMClassifier(random_state=42,class_weight = 'balanced')
}

# Definir as grades de hiperparâmetros para cada modelo
param_grids = {
    'RandomForest': {
        'n_estimators': [100, 200, 500,1000],
        'max_depth': [None, 10, 30],
        'min_samples_split': [2, 5, 10],
        'criterion': ['gini', 'entropy']
    },
    'XGBoost': {
        'n_estimators': [100, 200, 500,1000],
        'learning_rate': [0.001, 0.1, 0.3],
        'max_depth': [3, 6, 10],
        'num_leaves':[2,16,64,128],
        'min_child_samples':[1,40,70,100],
        
    },
    'LGBM':{
        'learning_rate': [0.001, 0.1, 0.3],
        'num_leaves':[2,16,64,128],
        'min_child_samples':[1,40,70,100],
        
        
    }
}

# Validação cruzada com 3 folds
cv = KFold(n_splits=3, shuffle=True, random_state=42)

# Treinar e ajustar os modelos
grids = {} # armazenará os modelos
for model_name, model in models.items():
    grids[model_name] = GridSearchCV(estimator=model, param_grid=param_grids[model_name], cv=cv, scoring='f1', n_jobs=-1, verbose=1)
    grids[model_name].fit(X_train, y_train)
    best_params = grids[model_name].best_params_
    best_score = grids[model_name].best_score_
    
    # Prever os rótulos do conjunto de teste
    y_pred = grids[model_name].predict(X_test)
    
    # Calcular o F1 score para o conjunto de teste
    f1 = f1_score(y_test, y_pred)
    
    # Imprimir os resultados
    print(f'Best parameters for {model_name}: {best_params}')
    print(f'Best F1 score for {model_name}: {best_score}')
    print(f'F1 score on test set for {model_name}: {f1}\n')
# Out:
# Fitting 3 folds for each of 72 candidates, totalling 216 fits
# Best parameters for RandomForest: {'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'n_estimators': 1000}
# Best F1 score for RandomForest: 0.7956325006081763
# F1 score on test set for RandomForest: 0.7970983571580968
#
# Fitting 3 folds for each of 576 candidates, totalling 1728 fits
# [11:55:09] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:09] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:10] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:11] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:14] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:17] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:23] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:24] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:25] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:25] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:26] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:28] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:31] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:34] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:40] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:41] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:41] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:42] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:43] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:44] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:47] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:50] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:57] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:57] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:58] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:59] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:56:00] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:56:01] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:56:04] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:56:07] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:56:13] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:56:15] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:56:16] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:56:17] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:56:20] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:56:26] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:56:33] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:56:46] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:56:47] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:56:48] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:56:50] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:56:52] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:56:55] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:57:02] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:57:08] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:57:21] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:57:22] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:57:24] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:57:25] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:57:28] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:57:30] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:57:37] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:57:43] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:57:57] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:57:58] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:57:59] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:58:01] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:58:03] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:58:06] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:58:12] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:58:19] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:58:32] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:58:34] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:58:36] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:58:39] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:09] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:09] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:10] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:11] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:14] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:17] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:23] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:24] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:24] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:25] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:26] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:28] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:31] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:34] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:40] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:40] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:41] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:42] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:43] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:44] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:47] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:50] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:57] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:57] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:58] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:58] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:56:00] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:56:01] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:56:04] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:56:07] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:56:13] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:56:15] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:56:16] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:56:17] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:56:20] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:56:26] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:56:33] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:56:46] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:56:47] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:56:48] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:56:50] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:56:52] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:56:55] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:57:01] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:57:08] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:57:21] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:57:22] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:57:23] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:57:25] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:57:27] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:57:30] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:57:33] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:57:39] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:57:52] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:58:05] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:58:08] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:58:14] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:58:28] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:58:40] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:58:45] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:58:57] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:59:09] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:59:33] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:59:35] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:59:38] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:09] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:09] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:11] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:12] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:15] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:21] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:27] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:28] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:31] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:38] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:44] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:47] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:50] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:57] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:57] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:58] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:59] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:56:00] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:56:01] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:56:04] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:56:07] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:56:13] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:56:15] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:56:16] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:56:17] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:56:20] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:56:26] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:56:33] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:56:46] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:56:48] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:56:49] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:56:50] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:56:53] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:56:56] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:57:02] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:57:09] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:57:22] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:57:23] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:57:24] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:57:26] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:57:28] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:57:31] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:57:38] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:57:44] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:57:57] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:57:59] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:58:00] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:58:01] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:58:04] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:58:07] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:58:13] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:58:20] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:58:33] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:58:35] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:58:38] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:58:40] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:58:45] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:58:57] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:59:09] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:59:33] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:59:35] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:59:38] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:59:40] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:59:45] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:59:50] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:09] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:09] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:10] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:11] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:14] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:17] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:23] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:24] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:25] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:25] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:26] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:28] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:31] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:34] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:40] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:40] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:41] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:42] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:43] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:44] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:47] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:50] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:57] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:57] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:58] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:55:59] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:56:00] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:56:01] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:56:04] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:56:07] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:56:13] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:56:15] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:56:16] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:56:17] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:56:20] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:56:26] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:56:33] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:56:46] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:56:47] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:56:48] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:56:50] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:56:52] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:56:55] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:56:57] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:57:04] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:57:17] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:57:30] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:57:32] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:57:39] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:57:52] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:58:05] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:58:08] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:58:14] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:58:27] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:58:40] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:58:45] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:58:57] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:59:09] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:59:32] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:59:35] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:59:37] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:59:40] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:59:45] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [11:59:49] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
#
# [12:00:02] WARNING: ../src/learner.cc:767:
# Parameters: { "class_weight", "min_child_samples", "num_leaves" } are not used.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_10484/3857236748.py in <module>
#      41 for model_name, model in models.items():
#      42     grids[model_name] = GridSearchCV(estimator=model, param_grid=param_grids[model_name], cv=cv, scoring='f1', n_jobs=-1, verbose=1)
# ---> 43     grids[model_name].fit(X_train, y_train)
#      44     best_params = grids[model_name].best_params_
#      45     best_score = grids[model_name].best_score_
#
# /opt/anaconda/lib/python3.9/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     889                 return results
#     890
# --> 891             self._run_search(evaluate_candidates)
#     892
#     893             # multimetric is determined here because in the case of a callable
#
# /opt/anaconda/lib/python3.9/site-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1390     def _run_search(self, evaluate_candidates):
#    1391         """Search all candidates in param_grid"""
# -> 1392         evaluate_candidates(ParameterGrid(self.param_grid))
#    1393
#    1394
#
# /opt/anaconda/lib/python3.9/site-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params, cv, more_results)
#     836                     )
#     837
# --> 838                 out = parallel(
#     839                     delayed(_fit_and_score)(
#     840                         clone(base_estimator),
#
# /opt/anaconda/lib/python3.9/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1054
#    1055             with self._backend.retrieval_context():
# -> 1056                 self.retrieve()
#    1057             # Make sure that we get a last message telling us we are done
#    1058             elapsed_time = time.time() - self._start_time
#
# /opt/anaconda/lib/python3.9/site-packages/joblib/parallel.py in retrieve(self)
#     933             try:
#     934                 if getattr(self._backend, 'supports_timeout', False):
# --> 935                     self._output.extend(job.get(timeout=self.timeout))
#     936                 else:
#     937                     self._output.extend(job.get())
#
# /opt/anaconda/lib/python3.9/site-packages/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     540         AsyncResults.get from multiprocessing."""
#     541         try:
# --> 542             return future.result(timeout=timeout)
#     543         except CfTimeoutError as e:
#     544             raise TimeoutError from e
#
# /opt/anaconda/lib/python3.9/concurrent/futures/_base.py in result(self, timeout)
#     439                     return self.__get_result()
#     440
# --> 441                 self._condition.wait(timeout)
#     442
#     443                 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# /opt/anaconda/lib/python3.9/threading.py in wait(self, timeout)
#     310         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     311             if timeout is None:
# --> 312                 waiter.acquire()
#     313                 gotit = True
#     314             else:
#
# KeyboardInterrupt:

# %%
from skopt import gp_minimize

def train_model_lgbm(params):
    # Dividir os dados em conjuntos de treinamento e teste
    X_train, X_test, y_train, y_test = train_test_split(X_preprocessed_fe, y, test_size=0.2, random_state=42)

    learning_rate = params[0]
    num_leaves = params[1]
    min_child_samples = params[2]
    subsample = params[3]
    colsample_bytree = params[4]
    
    print(params,'\n')
    
    mdl = LGBMClassifier(learning_rate=learning_rate, num_leaves=num_leaves, min_child_samples=min_child_samples,
                         subsample=subsample, colsample_bytree=colsample_bytree, random_state=42, subsample_freq=1, n_estimators=1000)
    mdl.fit(X_train, y_train)
    
    p = mdl.predict_proba(X_test)[:,1]
    
    return -roc_auc_score(y_test, p)

def train_model_xgboost(params):
    # Dividir os dados em conjuntos de treinamento e teste
    X_train, X_test, y_train, y_test = train_test_split(X_preprocessed_fe, y, test_size=0.2, random_state=42)

    learning_rate = params[0]
    num_leaves = params[1]
    min_child_samples = params[2]
    subsample = params[3]
    colsample_bytree = params[4]
    
    print(params,'\n')
    
    mdl = XGBClassifier(learning_rate=learning_rate, num_leaves=num_leaves, min_child_samples=min_child_samples,
                        subsample=subsample, colsample_bytree=colsample_bytree, random_state=42, n_estimators=1000)
    mdl.fit(X_train, y_train)
    
    p = mdl.predict_proba(X_test)[:,1]
    
    return -roc_auc_score(y_test, p)

def train_model_randomforest(params):
    # Dividir os dados em conjuntos de treinamento e teste
    X_train, X_test, y_train, y_test = train_test_split(X_preprocessed_fe, y, test_size=0.2, random_state=42)

    n_estimators = params[0]
    max_depth = params[1]
    min_samples_split = params[2]
    criterion = params[3]
    
    print(params,'\n')
    
    mdl = RandomForestClassifier(n_estimators=n_estimators, max_depth=max_depth, min_samples_split=min_samples_split,
                                 criterion=criterion, random_state=42, class_weight='balanced')
    mdl.fit(X_train, y_train)
    
    p = mdl.predict_proba(X_test)[:,1]
    
    return -roc_auc_score(y_test, p)

space_lgbm = [(1e-3, 1e-1, 'log-uniform'),  # learning_rate
              (2, 128),  # num_leaves
              (1, 100),  # min_child_samples
              (0.05, 1.0),  # subsample
              (0.1, 1.0)]  # colsample_bytree

space_xgboost = [(1e-3, 1e-1, 'log-uniform'),  # learning_rate
                 (2, 128),  # num_leaves
                 (1, 100),  # min_child_samples
                 (0.05, 1.0),  # subsample
                 (0.1, 1.0)]  # colsample_bytree

space_randomforest = [(100, 1000),  # n_estimators
                      (None, 10, 30),  # max_depth
                      (2, 5, 10),  # min_samples_split
                      ['gini', 'entropy']]  # criterion

resultado_gp_lgbm = gp_minimize(train_model_lgbm, space_lgbm, random_state=42, verbose=1, n_calls=30, n_random_starts=15)
resultado_gp_xgboost = gp_minimize(train_model_xgboost, space_xgboost, random_state=42, verbose=1, n_calls=30, n_random_starts=15)
resultado_gp_randomforest = gp_minimize(train_model_randomforest, space_randomforest, random_state=42, verbose=1, n_calls=30, n_random_starts=15)

best_params_lgbm = dict(zip(['learning_rate', 'num_leaves', 'min_child_samples', 'subsample', 'colsample_bytree'], resultado_gp_lgbm.x))
best_score_lgbm = -resultado_gp_lgbm.fun

best_params_xgboost = dict(zip(['learning_rate', 'num_leaves', 'min_child_samples', 'subsample', 'colsample_bytree'], resultado_gp_xgboost.x))
best_score_xgboost = -resultado_gp_xgboost.fun

best_params_randomforest = dict(zip(['n_estimators', 'max_depth', 'min_samples_split', 'criterion'], resultado_gp_randomforest.x))
best_score_randomforest = -resultado_gp_randomforest.fun

print('LGBM:')
print('Best parameters:', best_params_lgbm)
print('Best score:', best_score_lgbm)

print('\nXGBoost:')
print('Best parameters:', best_params_xgboost)
print('Best score:', best_score_xgboost)

print('\nRandomForest:')
print('Best parameters:', best_params_randomforest)
print('Best score:', best_score_randomforest)
# Out:
# Iteration No: 1 started. Evaluating function at random point.
# [0.03918194347141743, 25, 78, 0.6170076500491628, 0.5012494775682321]
#
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 0.6494
# Function value obtained: -0.7626
# Current minimum: -0.7626
# Iteration No: 2 started. Evaluating function at random point.
# [0.0015847101210439095, 60, 34, 0.18572347702584374, 0.6857996256539677]
#
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 0.8975
# Function value obtained: -0.7743
# Current minimum: -0.7743
# Iteration No: 3 started. Evaluating function at random point.
# [0.00129665117537604, 93, 94, 0.05073982754896361, 0.992990403362096]
#
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 0.2538
# Function value obtained: -0.7537
# Current minimum: -0.7743
# Iteration No: 4 started. Evaluating function at random point.
# [0.017177621112338382, 79, 2, 0.07190930378934497, 0.5722971942325503]
#
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 1.0452
# Function value obtained: -0.7484
# Current minimum: -0.7743
# Iteration No: 5 started. Evaluating function at random point.
# [0.006305535040199288, 8, 97, 0.27113277340878905, 0.18154579107953872]
#
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 0.3075
# Function value obtained: -0.7702
# Current minimum: -0.7743
# Iteration No: 6 started. Evaluating function at random point.
# [0.017249321573179006, 50, 98, 0.493424748585581, 0.8739463660626887]
#
# Iteration No: 6 ended. Evaluation done at random point.
# Time taken: 0.9710
# Function value obtained: -0.7626
# Current minimum: -0.7743
# Iteration No: 7 started. Evaluating function at random point.
# [0.022941144328643994, 59, 2, 0.9450916679006104, 0.6069593960609855]
#
# Iteration No: 7 ended. Evaluation done at random point.
# Time taken: 0.8739
# Function value obtained: -0.7633
# Current minimum: -0.7743
# Iteration No: 8 started. Evaluating function at random point.
# [0.005899741796710488, 4, 24, 0.2789741927247112, 0.7149371669429125]
#
# Iteration No: 8 ended. Evaluation done at random point.
# Time taken: 0.2596
# Function value obtained: -0.7713
# Current minimum: -0.7743
# Iteration No: 9 started. Evaluating function at random point.
# [0.016595613641357258, 107, 18, 0.4215075771945788, 0.2640124790092561]
#
# Iteration No: 9 ended. Evaluation done at random point.
# Time taken: 1.0930
# Function value obtained: -0.7597
# Current minimum: -0.7743
# Iteration No: 10 started. Evaluating function at random point.
# [0.0324132680419563, 56, 22, 0.5893153114289921, 0.12818196321000275]
#
# Iteration No: 10 ended. Evaluation done at random point.
# Time taken: 0.6620
# Function value obtained: -0.7595
# Current minimum: -0.7743
# Iteration No: 11 started. Evaluating function at random point.
# [0.04836927180682224, 59, 40, 0.9303259225041047, 0.7545447962707789]
#
# Iteration No: 11 ended. Evaluation done at random point.
# Time taken: 1.3748
# Function value obtained: -0.7356
# Current minimum: -0.7743
# Iteration No: 12 started. Evaluating function at random point.
# [0.004498643077694106, 74, 53, 0.9631134231318819, 0.8600804638103364]
#
# Iteration No: 12 ended. Evaluation done at random point.
# Time taken: 1.2667
# Function value obtained: -0.7757
# Current minimum: -0.7757
# Iteration No: 13 started. Evaluating function at random point.
# [0.031234907221207767, 70, 59, 0.9669925419009313, 0.6463308229180164]
#
# Iteration No: 13 ended. Evaluation done at random point.
# Time taken: 1.1456
# Function value obtained: -0.7464
# Current minimum: -0.7757
# Iteration No: 14 started. Evaluating function at random point.
# [0.0035644979070394624, 39, 17, 0.06485458640413425, 0.4810613326357328]
#
# Iteration No: 14 ended. Evaluation done at random point.
# Time taken: 0.6149
# Function value obtained: -0.7726
# Current minimum: -0.7757
# Iteration No: 15 started. Evaluating function at random point.
# [0.006162586615353729, 39, 2, 0.23890028388436496, 0.7402077574737851]
#
# Iteration No: 15 ended. Evaluation done at random point.
# Time taken: 0.8830
# Function value obtained: -0.7764
# Current minimum: -0.7764
# Iteration No: 16 started. Searching for the next optimal point.
# [0.001802723876330071, 27, 89, 0.7634224022814329, 1.0]
#
# Iteration No: 16 ended. Search finished for the next optimal point.
# Time taken: 0.9934
# Function value obtained: -0.7809
# Current minimum: -0.7809
# Iteration No: 17 started. Searching for the next optimal point.
# [0.0030225976257429545, 77, 48, 0.4756692677619401, 0.5165315127100337]
#
# Iteration No: 17 ended. Search finished for the next optimal point.
# Time taken: 1.3673
# Function value obtained: -0.7756
# Current minimum: -0.7809
# Iteration No: 18 started. Searching for the next optimal point.
# [0.006749168909839042, 45, 1, 1.0, 0.2782101211838157]
#
# Iteration No: 18 ended. Search finished for the next optimal point.
# Time taken: 0.9482
# Function value obtained: -0.7754
# Current minimum: -0.7809
# Iteration No: 19 started. Searching for the next optimal point.
# [0.001, 20, 10, 0.8352690200990482, 0.7499100552119942]
#
# Iteration No: 19 ended. Search finished for the next optimal point.
# Time taken: 0.8500
# Function value obtained: -0.7792
# Current minimum: -0.7809
# Iteration No: 20 started. Searching for the next optimal point.
# [0.0016793067281441326, 2, 29, 0.9778458399273235, 0.29499375816061213]
#
# Iteration No: 20 ended. Search finished for the next optimal point.
# Time taken: 0.4689
# Function value obtained: -0.7497
# Current minimum: -0.7809
# Iteration No: 21 started. Searching for the next optimal point.
# [0.0012491810097488424, 35, 73, 0.8630554310020496, 0.6840751595087813]
#
# Iteration No: 21 ended. Search finished for the next optimal point.
# Time taken: 1.1723
# Function value obtained: -0.7808
# Current minimum: -0.7809
# Iteration No: 22 started. Searching for the next optimal point.
# [0.001939456549844795, 42, 9, 0.803331021778477, 0.13640848879402753]
#
# Iteration No: 22 ended. Search finished for the next optimal point.
# Time taken: 0.7528
# Function value obtained: -0.7520
# Current minimum: -0.7809
# Iteration No: 23 started. Searching for the next optimal point.
# [0.015076221378604938, 2, 18, 1.0, 0.42432697676344455]
#
# Iteration No: 23 ended. Search finished for the next optimal point.
# Time taken: 0.4134
# Function value obtained: -0.7653
# Current minimum: -0.7809
# Iteration No: 24 started. Searching for the next optimal point.
# [0.0028042661889240163, 41, 34, 1.0, 0.7815938299262029]
#
# Iteration No: 24 ended. Search finished for the next optimal point.
# Time taken: 1.1470
# Function value obtained: -0.7822
# Current minimum: -0.7822
# Iteration No: 25 started. Searching for the next optimal point.
# [0.0028799091749902644, 128, 51, 1.0, 0.1]
#
# Iteration No: 25 ended. Search finished for the next optimal point.
# Time taken: 0.7914
# Function value obtained: -0.7549
# Current minimum: -0.7822
# Iteration No: 26 started. Searching for the next optimal point.
# [0.001, 44, 88, 1.0, 0.9375996759499089]
#
# Iteration No: 26 ended. Search finished for the next optimal point.
# Time taken: 1.1733
# Function value obtained: -0.7807
# Current minimum: -0.7822
# Iteration No: 27 started. Searching for the next optimal point.
# [0.001, 2, 100, 0.05, 1.0]
#
# Iteration No: 27 ended. Search finished for the next optimal point.
# Time taken: 0.4830
# Function value obtained: -0.7359
# Current minimum: -0.7822
# Iteration No: 28 started. Searching for the next optimal point.
# [0.0017957808263567283, 96, 9, 0.8484181309150723, 0.8325313833397626]
#
# Iteration No: 28 ended. Search finished for the next optimal point.
# Time taken: 1.7956
# Function value obtained: -0.7805
# Current minimum: -0.7822
# Iteration No: 29 started. Searching for the next optimal point.
# [0.0035506862302924456, 128, 16, 0.36614421377735307, 0.8372850929274959]
#
# Iteration No: 29 ended. Search finished for the next optimal point.
# Time taken: 2.1073
# Function value obtained: -0.7707
# Current minimum: -0.7822
# Iteration No: 30 started. Searching for the next optimal point.
# [0.0017119527394820464, 2, 78, 1.0, 0.8715279004228087]
#
# Iteration No: 30 ended. Search finished for the next optimal point.
# Time taken: 0.4013
# Function value obtained: -0.7304
# Current minimum: -0.7822
# Iteration No: 1 started. Evaluating function at random point.
# [0.03918194347141743, 25, 78, 0.6170076500491628, 0.5012494775682321]
#
# [11:43:04] WARNING: ../src/learner.cc:767:
# Parameters: { "min_child_samples", "num_leaves" } are not used.
#
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 2.6582
# Function value obtained: -0.7645
# Current minimum: -0.7645
# Iteration No: 2 started. Evaluating function at random point.
# [0.0015847101210439095, 60, 34, 0.18572347702584374, 0.6857996256539677]
#
# [11:43:07] WARNING: ../src/learner.cc:767:
# Parameters: { "min_child_samples", "num_leaves" } are not used.
#
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 2.2359
# Function value obtained: -0.7767
# Current minimum: -0.7767
# Iteration No: 3 started. Evaluating function at random point.
# [0.00129665117537604, 93, 94, 0.05073982754896361, 0.992990403362096]
#
# [11:43:09] WARNING: ../src/learner.cc:767:
# Parameters: { "min_child_samples", "num_leaves" } are not used.
#
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 1.9969
# Function value obtained: -0.7729
# Current minimum: -0.7767
# Iteration No: 4 started. Evaluating function at random point.
# [0.017177621112338382, 79, 2, 0.07190930378934497, 0.5722971942325503]
#
# [11:43:11] WARNING: ../src/learner.cc:767:
# Parameters: { "min_child_samples", "num_leaves" } are not used.
#
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 1.6354
# Function value obtained: -0.7667
# Current minimum: -0.7767
# Iteration No: 5 started. Evaluating function at random point.
# [0.006305535040199288, 8, 97, 0.27113277340878905, 0.18154579107953872]
#
# [11:43:13] WARNING: ../src/learner.cc:767:
# Parameters: { "min_child_samples", "num_leaves" } are not used.
#
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 1.3162
# Function value obtained: -0.7699
# Current minimum: -0.7767
# Iteration No: 6 started. Evaluating function at random point.
# [0.017249321573179006, 50, 98, 0.493424748585581, 0.8739463660626887]
#
# [11:43:14] WARNING: ../src/learner.cc:767:
# Parameters: { "min_child_samples", "num_leaves" } are not used.
#
# Iteration No: 6 ended. Evaluation done at random point.
# Time taken: 3.4699
# Function value obtained: -0.7708
# Current minimum: -0.7767
# Iteration No: 7 started. Evaluating function at random point.
# [0.022941144328643994, 59, 2, 0.9450916679006104, 0.6069593960609855]
#
# [11:43:18] WARNING: ../src/learner.cc:767:
# Parameters: { "min_child_samples", "num_leaves" } are not used.
#
# Iteration No: 7 ended. Evaluation done at random point.
# Time taken: 2.8470
# Function value obtained: -0.7749
# Current minimum: -0.7767
# Iteration No: 8 started. Evaluating function at random point.
# [0.005899741796710488, 4, 24, 0.2789741927247112, 0.7149371669429125]
#
# [11:43:20] WARNING: ../src/learner.cc:767:
# Parameters: { "min_child_samples", "num_leaves" } are not used.
#
# Iteration No: 8 ended. Evaluation done at random point.
# Time taken: 2.5869
# Function value obtained: -0.7781
# Current minimum: -0.7781
# Iteration No: 9 started. Evaluating function at random point.
# [0.016595613641357258, 107, 18, 0.4215075771945788, 0.2640124790092561]
#
# [11:43:23] WARNING: ../src/learner.cc:767:
# Parameters: { "min_child_samples", "num_leaves" } are not used.
#
# Iteration No: 9 ended. Evaluation done at random point.
# Time taken: 2.0245
# Function value obtained: -0.7767
# Current minimum: -0.7781
# Iteration No: 10 started. Evaluating function at random point.
# [0.0324132680419563, 56, 22, 0.5893153114289921, 0.12818196321000275]
#
# [11:43:25] WARNING: ../src/learner.cc:767:
# Parameters: { "min_child_samples", "num_leaves" } are not used.
#
# Iteration No: 10 ended. Evaluation done at random point.
# Time taken: 1.3967
# Function value obtained: -0.7708
# Current minimum: -0.7781
# Iteration No: 11 started. Evaluating function at random point.
# [0.04836927180682224, 59, 40, 0.9303259225041047, 0.7545447962707789]
#
# [11:43:26] WARNING: ../src/learner.cc:767:
# Parameters: { "min_child_samples", "num_leaves" } are not used.
#
# Iteration No: 11 ended. Evaluation done at random point.
# Time taken: 3.0540
# Function value obtained: -0.7630
# Current minimum: -0.7781
# Iteration No: 12 started. Evaluating function at random point.
# [0.004498643077694106, 74, 53, 0.9631134231318819, 0.8600804638103364]
#
# [11:43:29] WARNING: ../src/learner.cc:767:
# Parameters: { "min_child_samples", "num_leaves" } are not used.
#
# Iteration No: 12 ended. Evaluation done at random point.
# Time taken: 3.2913
# Function value obtained: -0.7832
# Current minimum: -0.7832
# Iteration No: 13 started. Evaluating function at random point.
# [0.031234907221207767, 70, 59, 0.9669925419009313, 0.6463308229180164]
#
# [11:43:33] WARNING: ../src/learner.cc:767:
# Parameters: { "min_child_samples", "num_leaves" } are not used.
#
# Iteration No: 13 ended. Evaluation done at random point.
# Time taken: 2.9736
# Function value obtained: -0.7704
# Current minimum: -0.7832
# Iteration No: 14 started. Evaluating function at random point.
# [0.0035644979070394624, 39, 17, 0.06485458640413425, 0.4810613326357328]
#
# [11:43:36] WARNING: ../src/learner.cc:767:
# Parameters: { "min_child_samples", "num_leaves" } are not used.
#
# Iteration No: 14 ended. Evaluation done at random point.
# Time taken: 1.5599
# Function value obtained: -0.7741
# Current minimum: -0.7832
# Iteration No: 15 started. Evaluating function at random point.
# [0.006162586615353729, 39, 2, 0.23890028388436496, 0.7402077574737851]
#
# [11:43:37] WARNING: ../src/learner.cc:767:
# Parameters: { "min_child_samples", "num_leaves" } are not used.
#
# Iteration No: 15 ended. Evaluation done at random point.
# Time taken: 2.5027
# Function value obtained: -0.7776
# Current minimum: -0.7832
# Iteration No: 16 started. Searching for the next optimal point.
# [0.0019477081675678457, 112, 5, 1.0, 0.7427981329621436]
#
# [11:43:40] WARNING: ../src/learner.cc:767:
# Parameters: { "min_child_samples", "num_leaves" } are not used.
#
# Iteration No: 16 ended. Search finished for the next optimal point.
# Time taken: 3.2543
# Function value obtained: -0.7803
# Current minimum: -0.7832
# Iteration No: 17 started. Searching for the next optimal point.
# [0.012622550521570434, 29, 81, 1.0, 0.1]
#
# [11:43:43] WARNING: ../src/learner.cc:767:
# Parameters: { "min_child_samples", "num_leaves" } are not used.
#
# Iteration No: 17 ended. Search finished for the next optimal point.
# Time taken: 1.0485
# Function value obtained: -0.7633
# Current minimum: -0.7832
# Iteration No: 18 started. Searching for the next optimal point.
# [0.005771087214636935, 104, 30, 1.0, 0.6102589094512604]
#
# [11:43:44] WARNING: ../src/learner.cc:767:
# Parameters: { "min_child_samples", "num_leaves" } are not used.
#
# Iteration No: 18 ended. Search finished for the next optimal point.
# Time taken: 3.1383
# Function value obtained: -0.7831
# Current minimum: -0.7832
# Iteration No: 19 started. Searching for the next optimal point.
# [0.008104666261083297, 20, 17, 1.0, 0.757448464561781]
#
# [11:43:47] WARNING: ../src/learner.cc:767:
# Parameters: { "min_child_samples", "num_leaves" } are not used.
#
# Iteration No: 19 ended. Search finished for the next optimal point.
# Time taken: 3.1384
# Function value obtained: -0.7815
# Current minimum: -0.7832
# Iteration No: 20 started. Searching for the next optimal point.
# [0.0010083554278993415, 105, 47, 0.963914116699128, 0.27191669384132167]
#
# [11:43:50] WARNING: ../src/learner.cc:767:
# Parameters: { "min_child_samples", "num_leaves" } are not used.
#
# Iteration No: 20 ended. Search finished for the next optimal point.
# Time taken: 2.3518
# Function value obtained: -0.7684
# Current minimum: -0.7832
# Iteration No: 21 started. Searching for the next optimal point.
# [0.0023458677436097256, 116, 93, 1.0, 1.0]
#
# [11:43:53] WARNING: ../src/learner.cc:767:
# Parameters: { "min_child_samples", "num_leaves" } are not used.
#
# Iteration No: 21 ended. Search finished for the next optimal point.
# Time taken: 3.5918
# Function value obtained: -0.7819
# Current minimum: -0.7832
# Iteration No: 22 started. Searching for the next optimal point.
# [0.0010354928965836505, 9, 29, 0.8715840665217528, 0.9551328221778435]
#
# [11:43:56] WARNING: ../src/learner.cc:767:
# Parameters: { "min_child_samples", "num_leaves" } are not used.
#
# Iteration No: 22 ended. Search finished for the next optimal point.
# Time taken: 3.5354
# Function value obtained: -0.7786
# Current minimum: -0.7832
# Iteration No: 23 started. Searching for the next optimal point.
# [0.1, 103, 72, 0.05, 0.1]
#
# [11:44:00] WARNING: ../src/learner.cc:767:
# Parameters: { "min_child_samples", "num_leaves" } are not used.
#
# Iteration No: 23 ended. Search finished for the next optimal point.
# Time taken: 1.0069
# Function value obtained: -0.7553
# Current minimum: -0.7832
# Iteration No: 24 started. Searching for the next optimal point.
# [0.00537836212028357, 128, 1, 0.6695112566974014, 0.6661853629499939]
#
# [11:44:01] WARNING: ../src/learner.cc:767:
# Parameters: { "min_child_samples", "num_leaves" } are not used.
#
# Iteration No: 24 ended. Search finished for the next optimal point.
# Time taken: 3.2954
# Function value obtained: -0.7814
# Current minimum: -0.7832
# Iteration No: 25 started. Searching for the next optimal point.
# [0.001, 71, 1, 0.05, 0.1]
#
# [11:44:04] WARNING: ../src/learner.cc:767:
# Parameters: { "min_child_samples", "num_leaves" } are not used.
#
# Iteration No: 25 ended. Search finished for the next optimal point.
# Time taken: 0.9945
# Function value obtained: -0.7549
# Current minimum: -0.7832
# Iteration No: 26 started. Searching for the next optimal point.
# [0.009349464833186676, 66, 23, 1.0, 1.0]
#
# [11:44:05] WARNING: ../src/learner.cc:767:
# Parameters: { "min_child_samples", "num_leaves" } are not used.
#
# Iteration No: 26 ended. Search finished for the next optimal point.
# Time taken: 3.3434
# Function value obtained: -0.7782
# Current minimum: -0.7832
# Iteration No: 27 started. Searching for the next optimal point.
# [0.003488176881398324, 2, 100, 0.6636456947488173, 0.9372020417065678]
#
# [11:44:08] WARNING: ../src/learner.cc:767:
# Parameters: { "min_child_samples", "num_leaves" } are not used.
#
# Iteration No: 27 ended. Search finished for the next optimal point.
# Time taken: 3.7524
# Function value obtained: -0.7820
# Current minimum: -0.7832
# Iteration No: 28 started. Searching for the next optimal point.
# [0.008491844392710635, 128, 100, 1.0, 0.4856823418694124]
#
# [11:44:12] WARNING: ../src/learner.cc:767:
# Parameters: { "min_child_samples", "num_leaves" } are not used.
#
# Iteration No: 28 ended. Search finished for the next optimal point.
# Time taken: 2.7431
# Function value obtained: -0.7813
# Current minimum: -0.7832
# Iteration No: 29 started. Searching for the next optimal point.
# [0.097911900114109, 76, 77, 0.07258478385979128, 0.975349343817673]
#
# [11:44:15] WARNING: ../src/learner.cc:767:
# Parameters: { "min_child_samples", "num_leaves" } are not used.
#
# Iteration No: 29 ended. Search finished for the next optimal point.
# Time taken: 2.5219
# Function value obtained: -0.7169
# Current minimum: -0.7832
# Iteration No: 30 started. Searching for the next optimal point.
# [0.1, 103, 22, 1.0, 0.1]
#
# [11:44:17] WARNING: ../src/learner.cc:767:
# Parameters: { "min_child_samples", "num_leaves" } are not used.
#
# Iteration No: 30 ended. Search finished for the next optimal point.
# Time taken: 1.0894
# Function value obtained: -0.7663
# Current minimum: -0.7832
# Iteration No: 1 started. Evaluating function at random point.
# [817, None, 10, 'gini']
#
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 6.8721
# Function value obtained: -0.7452
# Current minimum: -0.7452
# Iteration No: 2 started. Evaluating function at random point.
# [501, None, 5, 'entropy']
#
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 5.7876
# Function value obtained: -0.7305
# Current minimum: -0.7452
# Iteration No: 3 started. Evaluating function at random point.
# [229, 10, 2, 'gini']
#
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 1.3624
# Function value obtained: -0.7787
# Current minimum: -0.7787
# Iteration No: 4 started. Evaluating function at random point.
# [945, None, 10, 'gini']
#
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 8.1328
# Function value obtained: -0.7454
# Current minimum: -0.7787
# Iteration No: 5 started. Evaluating function at random point.
# [650, None, 2, 'gini']
#
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 6.1889
# Function value obtained: -0.7205
# Current minimum: -0.7787
# Iteration No: 6 started. Evaluating function at random point.
# [460, None, 10, 'entropy']
#
# Iteration No: 6 ended. Evaluation done at random point.
# Time taken: 5.0964
# Function value obtained: -0.7439
# Current minimum: -0.7787
# Iteration No: 7 started. Evaluating function at random point.
# [182, 10, 5, 'gini']
#
# Iteration No: 7 ended. Evaluation done at random point.
# Time taken: 1.0909
# Function value obtained: -0.7789
# Current minimum: -0.7789
# Iteration No: 8 started. Evaluating function at random point.
# [520, 30, 5, 'entropy']
#
# Iteration No: 8 ended. Evaluation done at random point.
# Time taken: 5.9694
# Function value obtained: -0.7327
# Current minimum: -0.7789
# Iteration No: 9 started. Evaluating function at random point.
# [112, 30, 5, 'entropy']
#
# Iteration No: 9 ended. Evaluation done at random point.
# Time taken: 1.2767
# Function value obtained: -0.7313
# Current minimum: -0.7789
# Iteration No: 10 started. Evaluating function at random point.
# [114, None, 2, 'gini']
#
# Iteration No: 10 ended. Evaluation done at random point.
# Time taken: 1.0891
# Function value obtained: -0.7180
# Current minimum: -0.7789
# Iteration No: 11 started. Evaluating function at random point.
# [649, 30, 2, 'entropy']
#
# Iteration No: 11 ended. Evaluation done at random point.
# Time taken: 7.7147
# Function value obtained: -0.7225
# Current minimum: -0.7789
# Iteration No: 12 started. Evaluating function at random point.
# [264, 30, 5, 'entropy']
#
# Iteration No: 12 ended. Evaluation done at random point.
# Time taken: 2.9910
# Function value obtained: -0.7324
# Current minimum: -0.7789
# Iteration No: 13 started. Evaluating function at random point.
# [611, None, 10, 'entropy']
#
# Iteration No: 13 ended. Evaluation done at random point.
# Time taken: 6.5312
# Function value obtained: -0.7440
# Current minimum: -0.7789
# Iteration No: 14 started. Evaluating function at random point.
# [456, 30, 5, 'entropy']
#
# Iteration No: 14 ended. Evaluation done at random point.
# Time taken: 5.1401
# Function value obtained: -0.7324
# Current minimum: -0.7789
# Iteration No: 15 started. Evaluating function at random point.
# [613, 10, 10, 'gini']
#
# Iteration No: 15 ended. Evaluation done at random point.
# Time taken: 3.6377
# Function value obtained: -0.7805
# Current minimum: -0.7805
# Iteration No: 16 started. Searching for the next optimal point.
# [1000, 10, 10, 'entropy']
#
# Iteration No: 16 ended. Search finished for the next optimal point.
# Time taken: 6.7259
# Function value obtained: -0.7799
# Current minimum: -0.7805
# Iteration No: 17 started. Searching for the next optimal point.
# [100, 10, 10, 'entropy']
#
# Iteration No: 17 ended. Search finished for the next optimal point.
# Time taken: 0.8606
# Function value obtained: -0.7786
# Current minimum: -0.7805
# Iteration No: 18 started. Searching for the next optimal point.
# [998, 10, 2, 'entropy']
#
# Iteration No: 18 ended. Search finished for the next optimal point.
# Time taken: 6.8257
# Function value obtained: -0.7798
# Current minimum: -0.7805
# Iteration No: 19 started. Searching for the next optimal point.
# [990, 30, 10, 'gini']
#
# Iteration No: 19 ended. Search finished for the next optimal point.
# Time taken: 8.4677
# Function value obtained: -0.7463
# Current minimum: -0.7805
# Iteration No: 20 started. Searching for the next optimal point.
# [1000, 10, 5, 'gini']
#
# Iteration No: 20 ended. Search finished for the next optimal point.
# Time taken: 5.9132
# Function value obtained: -0.7803
# Current minimum: -0.7805
# Iteration No: 21 started. Searching for the next optimal point.
# [1000, 10, 10, 'gini']
#
# Iteration No: 21 ended. Search finished for the next optimal point.
# Time taken: 5.7843
# Function value obtained: -0.7802
# Current minimum: -0.7805
# Iteration No: 22 started. Searching for the next optimal point.
# [1000, 10, 2, 'gini']
#
# Iteration No: 22 ended. Search finished for the next optimal point.
# Time taken: 5.9426
# Function value obtained: -0.7797
# Current minimum: -0.7805
# Iteration No: 23 started. Searching for the next optimal point.
# [1000, 10, 10, 'gini']
# /opt/anaconda/lib/python3.9/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Iteration No: 23 ended. Search finished for the next optimal point.
# Time taken: 5.8349
# Function value obtained: -0.7802
# Current minimum: -0.7805
# Iteration No: 24 started. Searching for the next optimal point.
# [100, 10, 2, 'entropy']
#
# Iteration No: 24 ended. Search finished for the next optimal point.
# Time taken: 0.9046
# Function value obtained: -0.7797
# Current minimum: -0.7805
# Iteration No: 25 started. Searching for the next optimal point.
# [1000, 10, 5, 'entropy']
#
# Iteration No: 25 ended. Search finished for the next optimal point.
# Time taken: 6.7781
# Function value obtained: -0.7801
# Current minimum: -0.7805
# Iteration No: 26 started. Searching for the next optimal point.
# [101, 10, 10, 'gini']
#
# Iteration No: 26 ended. Search finished for the next optimal point.
# Time taken: 0.8124
# Function value obtained: -0.7796
# Current minimum: -0.7805
# Iteration No: 27 started. Searching for the next optimal point.
# [1000, 10, 10, 'gini']
# /opt/anaconda/lib/python3.9/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Iteration No: 27 ended. Search finished for the next optimal point.
# Time taken: 5.8640
# Function value obtained: -0.7802
# Current minimum: -0.7805
# Iteration No: 28 started. Searching for the next optimal point.
# [1000, 10, 5, 'gini']
# /opt/anaconda/lib/python3.9/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Iteration No: 28 ended. Search finished for the next optimal point.
# Time taken: 5.8365
# Function value obtained: -0.7803
# Current minimum: -0.7805
# Iteration No: 29 started. Searching for the next optimal point.
# [105, 30, 10, 'entropy']
#
# Iteration No: 29 ended. Search finished for the next optimal point.
# Time taken: 1.3547
# Function value obtained: -0.7429
# Current minimum: -0.7805
# Iteration No: 30 started. Searching for the next optimal point.
# [100, 10, 5, 'entropy']
#
# Iteration No: 30 ended. Search finished for the next optimal point.
# Time taken: 0.9118
# Function value obtained: -0.7802
# Current minimum: -0.7805
# LGBM:
# Best parameters: {'learning_rate': 0.0028042661889240163, 'num_leaves': 41, 'min_child_samples': 34, 'subsample': 1.0, 'colsample_bytree': 0.7815938299262029}
# Best score: 0.7821784000820071
#
# XGBoost:
# Best parameters: {'learning_rate': 0.004498643077694106, 'num_leaves': 74, 'min_child_samples': 53, 'subsample': 0.9631134231318819, 'colsample_bytree': 0.8600804638103364}
# Best score: 0.7832200923157331
#
# RandomForest:
# Best parameters: {'n_estimators': 613, 'max_depth': 10, 'min_samples_split': 10, 'criterion': 'gini'}
# Best score: 0.7804770777176039

# %% [markdown]
# ### Random Forest
# - Fitting 3 folds for each of 54 candidates, totalling 162 fits
# - Best parameters for RandomForest: {'criterion': 'gini', 'max_depth': 30, 'min_samples_split': 2, 'n_estimators': 500}
# - Best F1 score for RandomForest: 0.803983160450065
# - F1 score on test set for RandomForest: 0.8011928429423459
#
# ### Xgboost
# - Fitting 3 folds for each of 27 candidates, totalling 81 fits
# - Best parameters for XGBoost: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 500}
# - Best F1 score for XGBoost: 0.8237540956961373
# - F1 score on test set for XGBoost: 0.8294094944037051

# %% [markdown]
# ## Submitions

# %%
df_test = pd.read_csv('data/test.csv')

# %%
df_test
# Out:
#      id_do_caso        continente educacao_do_empregado  \
# 0     EZYV22339              Ásia       Ensino Superior
# 1      EZYV9333              Ásia              Mestrado
# 2      EZYV9740              Ásia       Ensino Superior
# 3      EZYV3328              Ásia       Ensino Superior
# 4     EZYV12321    América do Sul       Ensino Superior
# ...         ...               ...                   ...
# 7639  EZYV19907  América do Norte       Ensino Superior
# 7640    EZYV576              Ásia          Ensino Médio
# 7641   EZYV1804              Ásia              Mestrado
# 7642  EZYV13543  América do Norte              Mestrado
# 7643  EZYV17903              Ásia       Ensino Superior
#
#      tem_experiencia_de_trabalho requer_treinamento_de_trabalho  \
# 0                              S                              N
# 1                              N                              S
# 2                              S                              N
# 3                              S                              N
# 4                              S                              S
# ...                          ...                            ...
# 7639                           N                              N
# 7640                           S                              N
# 7641                           S                              N
# 7642                           S                              N
# 7643                           S                              N
#
#       num_de_empregados  ano_de_estabelecimento regiao_de_emprego  \
# 0                  2414                    1973          Nordeste
# 1                  2928                    1937             Oeste
# 2                  1836                    1999             Oeste
# 3                   122                    2004               Sul
# 4                  1720                    2003          Nordeste
# ...                 ...                     ...               ...
# 7639                 66                    2008             Oeste
# 7640               4040                    1994        Meio-Oeste
# 7641              32503                    1925               Sul
# 7642               1894                    2000               Sul
# 7643               3676                    2007             Oeste
#
#       salario_prevalecente unidade_de_salario posicao_em_tempo_integral
# 0               103320.800                Ano                         N
# 1                49786.350                Ano                         S
# 2                60855.830                Ano                         S
# 3                82379.060             Semana                         S
# 4                 6719.810                Ano                         S
# ...                    ...                ...                       ...
# 7639                70.599               Hora                         S
# 7640             60158.590                Ano                         S
# 7641             44555.120                Ano                         S
# 7642             97830.730                Ano                         S
# 7643              7215.390                Ano                         S
#
# [7644 rows x 11 columns]

# %%
df_test_processed = pipeline_fe.transform(df_test)

# %%
df_test['status_do_caso'] = grids['XGBoost'].predict(df_test_processed)

# %%
submit_resp = df_test[['id_do_caso', 'status_do_caso']]

# %%
submit_resp
# Out:
#      id_do_caso  status_do_caso
# 0     EZYV22339               1
# 1      EZYV9333               1
# 2      EZYV9740               1
# 3      EZYV3328               1
# 4     EZYV12321               1
# ...         ...             ...
# 7639  EZYV19907               0
# 7640    EZYV576               0
# 7641   EZYV1804               1
# 7642  EZYV13543               1
# 7643  EZYV17903               1
#
# [7644 rows x 2 columns]

# %%
submit_resp.to_csv('submission_2.csv', index=False)
